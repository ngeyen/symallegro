# %% [markdown]
# # Allegro Model Training Pipeline
#
# This notebook runs the full training pipeline for the Allegro model using the aspirin dataset.
# Training dynamics (loss, metrics) are logged to Weights & Biases.

# %%
import sys
import os

# Add project root to path to allow imports from src and model
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# Ensure we are in the correct directory for relative paths if needed
os.chdir(project_root)

# %%
from src.train import main

print("Starting training pipeline...")
try:
    main()
    print("Training completed successfully.")
except Exception as e:
    print(f"An error occurred during training: {e}")
    raise e

# %% [markdown]
# ## Monitoring
#
# Training progress can be monitored in real-time using [Weights & Biases](https://wandb.ai/).
